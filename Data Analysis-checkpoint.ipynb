# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
jan= pd.read_csv("C:\\Users\\ysour\\OneDrive\\Desktop\\project\\New folder\\Sales_Data\\Sales_January_2019.csv")
feb= pd.read_csv("C:\\Users\\ysour\\OneDrive\\Desktop\\project\\New folder\\Sales_Data\\Sales_February_2019.csv")
mar= pd.read_csv("C:\\Users\\ysour\\OneDrive\\Desktop\\project\\New folder\\Sales_Data\\Sales_March_2019.csv")
apr= pd.read_csv("C:\\Users\\ysour\\OneDrive\\Desktop\\project\\New folder\\Sales_Data\\Sales_April_2019.csv")
may= pd.read_csv("C:\\Users\\ysour\\OneDrive\\Desktop\\project\\New folder\\Sales_Data\\Sales_May_2019.csv")
jun= pd.read_csv("C:\\Users\\ysour\\OneDrive\\Desktop\\project\\New folder\\Sales_Data\\Sales_June_2019.csv")
jul= pd.read_csv("C:\\Users\\ysour\\OneDrive\\Desktop\\project\\New folder\\Sales_Data\\Sales_July_2019.csv")
aug= pd.read_csv("C:\\Users\\ysour\\OneDrive\\Desktop\\project\\New folder\\Sales_Data\\Sales_August_2019.csv")
sep= pd.read_csv("C:\\Users\\ysour\\OneDrive\\Desktop\\project\\New folder\\Sales_Data\\Sales_September_2019.csv")
oct= pd.read_csv("C:\\Users\\ysour\\OneDrive\\Desktop\\project\\New folder\\Sales_Data\\Sales_October_2019.csv")
nov= pd.read_csv("C:\\Users\\ysour\\OneDrive\\Desktop\\project\\New folder\\Sales_Data\\Sales_November_2019.csv")
dec= pd.read_csv("C:\\Users\\ysour\\OneDrive\\Desktop\\project\\New folder\\Sales_Data\\Sales_December_2019.csv")

# %%
df=pd.concat([jan,feb,mar,apr,may,jun,jul,aug,sep,oct,nov,dec],axis=0)

# %%
df.head()
# Out:
#   Order ID                   Product Quantity Ordered Price Each  \
# 0   141234                    iPhone                1        700
# 1   141235  Lightning Charging Cable                1      14.95
# 2   141236          Wired Headphones                2      11.99
# 3   141237          27in FHD Monitor                1     149.99
# 4   141238          Wired Headphones                1      11.99
#
#        Order Date                       Purchase Address
# 0  01/22/19 21:25        944 Walnut St, Boston, MA 02215
# 1  01/28/19 14:15       185 Maple St, Portland, OR 97035
# 2  01/17/19 13:33  538 Adams St, San Francisco, CA 94016
# 3  01/05/19 20:33     738 10th St, Los Angeles, CA 90001
# 4  01/25/19 11:59          387 10th St, Austin, TX 73301

# %% [markdown]
# #### Preprocessing

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 186850 entries, 0 to 25116
# Data columns (total 6 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Order ID          186305 non-null  object
#  1   Product           186305 non-null  object
#  2   Quantity Ordered  186305 non-null  object
#  3   Price Each        186305 non-null  object
#  4   Order Date        186305 non-null  object
#  5   Purchase Address  186305 non-null  object
# dtypes: object(6)
# memory usage: 10.0+ MB

# %%
df['month']=df['Order Date'].str[0:2]

# %%
df
# Out:
#       Order ID                     Product Quantity Ordered Price Each  \
# 0       141234                      iPhone                1        700
# 1       141235    Lightning Charging Cable                1      14.95
# 2       141236            Wired Headphones                2      11.99
# 3       141237            27in FHD Monitor                1     149.99
# 4       141238            Wired Headphones                1      11.99
# ...        ...                         ...              ...        ...
# 25112   319666    Lightning Charging Cable                1      14.95
# 25113   319667       AA Batteries (4-pack)                2       3.84
# 25114   319668             Vareebadd Phone                1        400
# 25115   319669            Wired Headphones                1      11.99
# 25116   319670  Bose SoundSport Headphones                1      99.99
#
#            Order Date                        Purchase Address month
# ...

# %%
df.isnull().sum()
# Out:
# Order ID            545
# Product             545
# Quantity Ordered    545
# Price Each          545
# Order Date          545
# Purchase Address    545
# month               545
# dtype: int64

# %%
df=df.dropna()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 186305 entries, 0 to 25116
# Data columns (total 7 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Order ID          186305 non-null  object
#  1   Product           186305 non-null  object
#  2   Quantity Ordered  186305 non-null  object
#  3   Price Each        186305 non-null  object
#  4   Order Date        186305 non-null  object
#  5   Purchase Address  186305 non-null  object
#  6   month             186305 non-null  object
# dtypes: object(7)
# memory usage: 11.4+ MB

# %%
df=df[df['month'].str[0:2]!='Or']

# %%
df['Order Date']=pd.to_datetime(df['Order Date'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 185950 entries, 0 to 25116
# Data columns (total 7 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Order ID          185950 non-null  object
#  1   Product           185950 non-null  object
#  2   Quantity Ordered  185950 non-null  object
#  3   Price Each        185950 non-null  object
#  4   Order Date        185950 non-null  datetime64[ns]
#  5   Purchase Address  185950 non-null  object
#  6   month             185950 non-null  object
# dtypes: datetime64[ns](1), object(6)
# memory usage: 11.3+ MB

# %%
df['Month']=df['Order Date'].apply(lambda x:x.month)      #df['month']=df['Order Date'].str[0:2]
df['Month']=pd.to_numeric(df['month'])

# %%
df['Price Each']=pd.to_numeric(df['Price Each'])
df['Quantity Ordered']=pd.to_numeric(df['Quantity Ordered'])

# %%
df['Sales']=df['Quantity Ordered']*df['Price Each']

# %%
df
# Out:
#       Order ID                     Product  Quantity Ordered  Price Each  \
# 0       141234                      iPhone                 1      700.00
# 1       141235    Lightning Charging Cable                 1       14.95
# 2       141236            Wired Headphones                 2       11.99
# 3       141237            27in FHD Monitor                 1      149.99
# 4       141238            Wired Headphones                 1       11.99
# ...        ...                         ...               ...         ...
# 25112   319666    Lightning Charging Cable                 1       14.95
# 25113   319667       AA Batteries (4-pack)                 2        3.84
# 25114   319668             Vareebadd Phone                 1      400.00
# 25115   319669            Wired Headphones                 1       11.99
# 25116   319670  Bose SoundSport Headphones                 1       99.99
#
#                Order Date                        Purchase Address month  \
# ...

# %%
df['City']=df['Purchase Address'].apply(lambda x:x.split(',')[1])
df['State']=df['Purchase Address'].apply(lambda x:x.split(',')[2].split(' ')[1])

# %%
df
# Out:
#       Order ID                     Product  Quantity Ordered  Price Each  \
# 0       141234                      iPhone                 1      700.00
# 1       141235    Lightning Charging Cable                 1       14.95
# 2       141236            Wired Headphones                 2       11.99
# 3       141237            27in FHD Monitor                 1      149.99
# 4       141238            Wired Headphones                 1       11.99
# ...        ...                         ...               ...         ...
# 25112   319666    Lightning Charging Cable                 1       14.95
# 25113   319667       AA Batteries (4-pack)                 2        3.84
# 25114   319668             Vareebadd Phone                 1      400.00
# 25115   319669            Wired Headphones                 1       11.99
# 25116   319670  Bose SoundSport Headphones                 1       99.99
#
#                Order Date                        Purchase Address month  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 185950 entries, 0 to 25116
# Data columns (total 11 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Order ID          185950 non-null  object
#  1   Product           185950 non-null  object
#  2   Quantity Ordered  185950 non-null  int64
#  3   Price Each        185950 non-null  float64
#  4   Order Date        185950 non-null  datetime64[ns]
#  5   Purchase Address  185950 non-null  object
#  6   month             185950 non-null  object
#  7   Month             185950 non-null  int64
#  8   Sales             185950 non-null  float64
#  9   City              185950 non-null  object
#  10  State             185950 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(2), object(6)
# memory usage: 17.0+ MB

# %%
df['City'] = df['City'] +' '+ df['State']

# %%
df.drop(columns=['State'],axis=1,inplace=True)

# %%
df
# Out:
#       Order ID                     Product  Quantity Ordered  Price Each  \
# 0       141234                      iPhone                 1      700.00
# 1       141235    Lightning Charging Cable                 1       14.95
# 2       141236            Wired Headphones                 2       11.99
# 3       141237            27in FHD Monitor                 1      149.99
# 4       141238            Wired Headphones                 1       11.99
# ...        ...                         ...               ...         ...
# 25112   319666    Lightning Charging Cable                 1       14.95
# 25113   319667       AA Batteries (4-pack)                 2        3.84
# 25114   319668             Vareebadd Phone                 1      400.00
# 25115   319669            Wired Headphones                 1       11.99
# 25116   319670  Bose SoundSport Headphones                 1       99.99
#
#                Order Date                        Purchase Address month  \
# ...

# %%
df['Hour']=df['Order Date'].dt.hour
df['Minute']=df['Order Date'].dt.minute
df.head()
# Out:
#   Order ID                   Product  Quantity Ordered  Price Each  \
# 0   141234                    iPhone                 1      700.00
# 1   141235  Lightning Charging Cable                 1       14.95
# 2   141236          Wired Headphones                 2       11.99
# 3   141237          27in FHD Monitor                 1      149.99
# 4   141238          Wired Headphones                 1       11.99
#
#            Order Date                       Purchase Address month  Month  \
# 0 2019-01-22 21:25:00        944 Walnut St, Boston, MA 02215    01      1
# 1 2019-01-28 14:15:00       185 Maple St, Portland, OR 97035    01      1
# 2 2019-01-17 13:33:00  538 Adams St, San Francisco, CA 94016    01      1
# 3 2019-01-05 20:33:00     738 10th St, Los Angeles, CA 90001    01      1
# 4 2019-01-25 11:59:00          387 10th St, Austin, TX 73301    01      1
#
#     Sales               City  Hour  Minute
# 0  700.00          Boston MA    21      25
# ...

# %%
df1=df[df['Order ID'].duplicated(keep=False)]
df1['Grouped']=df1.groupby('Order ID')['Product'].transform(lambda x: ','.join(x))
# Out:
# C:\Users\ysour\AppData\Local\Temp/ipykernel_9036/2398629267.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['Grouped']=df1.groupby('Order ID')['Product'].transform(lambda x: ','.join(x))

# %%
df1=df1.drop_duplicates(subset=['Order ID', 'Grouped'], keep='last')

# %%
df1['Order ID'].nunique()
# Out:
# 7136

# %% [markdown]
# #### Question 1: What was the best month for sales? How much was earned that month?

# %%
sales_value=df.groupby('month').sum()

# %%
sales_value
# Out:
#        Quantity Ordered  Price Each   Month       Sales    Hour  Minute
# month
# 01                10903  1811768.38    9709  1822256.73  139485  282440
# 02                13449  2188884.72   23950  2202022.42  172669  354885
# 03                17005  2791207.83   45459  2807100.38  218969  447559
# 04                20558  3367671.02   73116  3390670.24  262259  544186
# 05                18667  3135125.13   82830  3152606.75  238780  487899
# 06                15253  2562025.61   81324  2577802.26  195528  402436
# 07                16072  2632539.56  100051  2647775.76  206169  417349
# 08                13448  2230345.42   95688  2244467.88  172289  353857
# 09                13109  2084992.09  104589  2097560.13  168513  341698
# 10                22703  3715554.83  202820  3736726.88  290650  598437
# 11                19798  3180600.68  193303  3199603.20  254865  518231
# 12                28114  4588415.41  299808  4613443.34  359978  733082

# %%
plt.bar(month,sales_value['Sales'])
plt.xlabel('Months')
plt.ylabel('Sales Amount')
plt.title('Bar Plot Between Months and Sales')
plt.show()

# %% [markdown]
# #### Question 2: What city sold the most product?

# %%
City_Sale=df.groupby('City').sum()

# %%
City_Sale
# Out:
#                    Quantity Ordered  Price Each   Month       Sales    Hour  \
# City
#  Atlanta GA                   16602  2779908.20  104794  2795498.58  214264
#  Austin TX                    11153  1809873.61   69829  1819581.75  141946
#  Boston MA                    22528  3637409.77  141112  3661642.01  288225
#  Dallas TX                    16730  2752627.82  104620  2767975.40  214390
#  Los Angeles CA               33289  5421435.23  208325  5452570.80  427444
#  New York City NY             27932  4635370.83  175741  4664317.43  357696
#  Portland ME                   2750   447189.25   17144   449758.27   35211
#  Portland OR                  11303  1860558.22   70621  1870732.34  144421
#  San Francisco CA             50239  8211461.74  315520  8262203.91  643265
#  Seattle WA                   16553  2733296.01  104941  2747755.48  213292
#
#                     Minute
# City
#  Atlanta GA         442932
#  Austin TX          289060
#  Boston MA          590442
# ...

# %%
city = [city for city, df  in df.groupby('City')]   #city=df['City'].unique()

# %%
plt.bar(city,City_Sale['Sales'])
plt.xticks(rotation=90)
plt.xlabel('Cities')
plt.ylabel('Sales')
plt.title('Bar Plot Between Cities and Sales')
plt.show()

# %% [markdown]
# #### Question 3: What time should we display advertisemens to maximize the likelihood of customer’s buying product?

# %%
hours = [hours for hours, df  in df.groupby('Hour')]
plt.plot(hours,df.groupby('Hour').count())
plt.grid()
plt.xlabel('Day Hours')
plt.ylabel('Order Placed')
plt.title('Purchase Distribution')
plt.show()

# %% [markdown]
# #### Question 4: What products are most often sold together?

# %%
df1['Grouped'].value_counts().head(10)
# Out:
# iPhone,Lightning Charging Cable                       882
# Google Phone,USB-C Charging Cable                     856
# iPhone,Wired Headphones                               361
# Vareebadd Phone,USB-C Charging Cable                  312
# Google Phone,Wired Headphones                         303
# iPhone,Apple Airpods Headphones                       286
# Google Phone,Bose SoundSport Headphones               161
# Vareebadd Phone,Wired Headphones                      104
# Google Phone,USB-C Charging Cable,Wired Headphones     77
# Vareebadd Phone,Bose SoundSport Headphones             60
# Name: Grouped, dtype: int64

# %% [markdown]
# #### Question 5: What product sold the most? Why do you think it sold the most?

# %%
Quantity=df.groupby('Product').sum()['Quantity Ordered']

# %%
Quantity
# Out:
# Product
# 20in Monitor                   4129
# 27in 4K Gaming Monitor         6244
# 27in FHD Monitor               7550
# 34in Ultrawide Monitor         6199
# AA Batteries (4-pack)         27635
# AAA Batteries (4-pack)        31017
# Apple Airpods Headphones      15661
# Bose SoundSport Headphones    13457
# Flatscreen TV                  4819
# Google Phone                   5532
# LG Dryer                        646
# LG Washing Machine              666
# Lightning Charging Cable      23217
# Macbook Pro Laptop             4728
# ThinkPad Laptop                4130
# USB-C Charging Cable          23975
# Vareebadd Phone                2068
# Wired Headphones              20557
# iPhone                         6849
# Name: Quantity Ordered, dtype: int64

# %%
Product = [Product for Product, df  in df.groupby('Product')]
plt.bar(Product,Quantity)
plt.xticks(rotation=90)
plt.xlabel('Product')
plt.ylabel('Quantity Ordered')
plt.title('Bar Plot Between Product and Quantity of Product')
plt.show()

# %%
Price=df.groupby('Product').mean()['Price Each']

# %%
Price
# Out:
# Product
# 20in Monitor                   109.99
# 27in 4K Gaming Monitor         389.99
# 27in FHD Monitor               149.99
# 34in Ultrawide Monitor         379.99
# AA Batteries (4-pack)            3.84
# AAA Batteries (4-pack)           2.99
# Apple Airpods Headphones       150.00
# Bose SoundSport Headphones      99.99
# Flatscreen TV                  300.00
# Google Phone                   600.00
# LG Dryer                       600.00
# LG Washing Machine             600.00
# Lightning Charging Cable        14.95
# Macbook Pro Laptop            1700.00
# ThinkPad Laptop                999.99
# USB-C Charging Cable            11.95
# Vareebadd Phone                400.00
# Wired Headphones                11.99
# iPhone                         700.00
# Name: Price Each, dtype: float64

# %%
fig, ax1=plt.subplots()
ax2=ax1.twinx()
ax1.bar(Product,Quantity,color='green')
ax2.plot(Product,Price,color='b')
ax1.set_xlabel('Product Name')
ax1.set_ylabel('Ordered Quantity')
ax2.set_ylabel('Price')
ax1.set_xticklabels(Product,rotation='vertical',size=8)

plt.show()
# Out:
# C:\Users\ysour\AppData\Local\Temp/ipykernel_9036/805139281.py:8: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax1.set_xticklabels(Product,rotation='vertical',size=8)
